# %% [markdown]
# # Loading Libraries

# %%
import pandas as pd
import numpy as np

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
df=pd.read_csv('mtcars.csv')
df.head()
# Out:
#           Unnamed: 0   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
# first put your predictors in x

x=df.drop(['mpg','Unnamed: 0'],axis=1)

# %%
x.head()
# Out:
#    cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# 1    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 2    4  108.0   93  3.85  2.320  18.61   1   1     4     1
# 3    6  258.0  110  3.08  3.215  19.44   1   0     3     1
# 4    8  360.0  175  3.15  3.440  17.02   0   0     3     2

# %%
# VIF dataframe
vif_data=pd.DataFrame()
vif_data['feature']=x.columns

# calculating VIF for each features
vif_data['VIF']=[variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
print(vif_data)
# Out:
#   feature         VIF
# 0     cyl  112.629828
# 1    disp   98.930791
# 2      hp   56.047781
# 3    drat  132.214353
# 4      wt  182.948049
# 5    qsec  317.534376
# 6      vs    8.752581
# 7      am    7.412020
# 8    gear  119.804879
# 9    carb   32.213836

# %%
# These how you check for vif

# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
df=pd.read_csv('mtcars.csv')
df.head()
# Out:
#           Unnamed: 0   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
x=df.drop(['Unnamed: 0','mpg'],axis=1)

# %%
x.columns
# Out:
# Index(['cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am', 'gear', 'carb'], dtype='object')

# %%
from sklearn.preprocessing import StandardScaler

# %%
# Before performing VIF your data should be standardized so first use standard scaler to make all the data in the same format

sc=StandardScaler()
x=sc.fit_transform(x)
x[0:2]
# Out:
# array([[-0.10666772, -0.57975032, -0.54365487,  0.57659448, -0.62016658,
#         -0.78960058, -0.8819171 ,  1.20894105,  0.43033148,  0.74696708],
#        [-0.10666772, -0.57975032, -0.54365487,  0.57659448, -0.35538219,
#         -0.47120178, -0.8819171 ,  1.20894105,  0.43033148,  0.74696708]])

# %%
x=pd.DataFrame(x,columns=['cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am', 'gear', 'carb'])

# %%
x.head(2)
# Out:
#         cyl     disp        hp      drat        wt      qsec        vs  \
# 0 -0.106668 -0.57975 -0.543655  0.576594 -0.620167 -0.789601 -0.881917
# 1 -0.106668 -0.57975 -0.543655  0.576594 -0.355382 -0.471202 -0.881917
#
#          am      gear      carb
# 0  1.208941  0.430331  0.746967
# 1  1.208941  0.430331  0.746967

# %%
data_vif=pd.DataFrame()
data_vif['Feature']=x.columns

data_vif['VIF']=[variance_inflation_factor(x.values,i)  for i in range(len(x.columns))]
data_vif
# Out:
#   Feature        VIF
# 0     cyl  15.373833
# 1    disp  21.620241
# 2      hp   9.832037
# 3    drat   3.374620
# 4      wt  15.164887
# 5    qsec   7.527958
# 6      vs   4.965873
# 7      am   4.648487
# 8    gear   5.357452
# 9    carb   7.908747

# %%
plt.figure(figsize=(15,10))
sns.heatmap(x.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
sc_df.corr()
# Out:
#            cyl      disp        hp      drat        wt      qsec        vs  \
# cyl   1.000000  0.902033  0.832447 -0.699938  0.782496 -0.591242 -0.810812
# disp  0.902033  1.000000  0.790949 -0.710214  0.887980 -0.433698 -0.710416
# hp    0.832447  0.790949  1.000000 -0.448759  0.658748 -0.708223 -0.723097
# drat -0.699938 -0.710214 -0.448759  1.000000 -0.712441  0.091205  0.440278
# wt    0.782496  0.887980  0.658748 -0.712441  1.000000 -0.174716 -0.554916
# qsec -0.591242 -0.433698 -0.708223  0.091205 -0.174716  1.000000  0.744535
# vs   -0.810812 -0.710416 -0.723097  0.440278 -0.554916  0.744535  1.000000
# am   -0.522607 -0.591227 -0.243204  0.712711 -0.692495 -0.229861  0.168345
# gear -0.492687 -0.555569 -0.125704  0.699610 -0.583287 -0.212682  0.206023
# carb  0.526988  0.394977  0.749812 -0.090790  0.427606 -0.656249 -0.569607
#
#             am      gear      carb
# cyl  -0.522607 -0.492687  0.526988
# disp -0.591227 -0.555569  0.394977
# hp   -0.243204 -0.125704  0.749812
# ...
